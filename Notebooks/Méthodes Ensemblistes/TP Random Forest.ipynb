# %%
import pandas as pd 
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
rawDataTrain = pd.read_csv("../../DataSet/RandomForest/train.csv")
rawDataTest = pd.read_csv("../../DataSet/RandomForest/test.csv")

# %%
rawDataTest.shape
# Out:
# (2947, 563)

# %%
rawDataTrain
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
y_train = rawDataTrain.values[:, -1]
y_test = rawDataTest.values[:, -1]
X_train = rawDataTrain.values[:, :-2]
X_test = rawDataTest.values[:, :-2]

# %%
classifier = RandomForestClassifier(n_estimators=1000)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
#selection des features importantes 
from sklearn.feature_selection import SelectFromModel
model = SelectFromModel(classifier, prefit=True, threshold=0.008)
#model.fit(X_train, y_train)
train_x2 = model.transform(X_train)
test_x2 = model.transform(X_test)
train_x2.shape
#il reste 22 features sur les 563 initiales
# Out:
# (7352, 22)

# %%
from sklearn.metrics import accuracy_score
classifier2 = RandomForestClassifier(n_estimators=1000)
classifier2.fit(train_x2, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
y_pred_2 = classifier2.predict(test_x2)
outAccuracy2 = accuracy_score(y_test, y_pred_2)
print("Accuracy 2", outAccuracy2)
y_pred = classifier.predict(X_test)
outAccuracy = accuracy_score(y_test, y_pred)
print("Accuracy 1", outAccuracy)
# Out:
# Accuracy 2 0.8106549032914828
# Accuracy 1 0.9297590770274856

# %%
# Courbe ROC no roc for mutliclasses
fpr, tpr, thr = metrics.roc_curve(y_test, y_pred)
fpr2, tpr2, thr2 = metrics.roc_curve(y_test, y_pred_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-411f75df47c3> in <module>
#       1 # Courbe ROC
# ----> 2 fpr, tpr, thr = metrics.roc_curve(y_test, y_pred)
#       3 fpr2, tpr2, thr2 = metrics.roc_curve(y_test, y_pred_2)
#
# ~/.local/share/virtualenvs/Seattle2050-kF-VE2eh/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/share/virtualenvs/Seattle2050-kF-VE2eh/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     911
#     912     """
# --> 913     fps, tps, thresholds = _binary_clf_curve(
# ...

# %%
# Out:
# array(['LAYING', 'SITTING', 'STANDING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS'], dtype=object)
